# %% [markdown]
# # Deep Learning Algoritmaları ile Fotoğraflardaki Nesneleri Tanıma ve Sınıflandırma Projesi
#
# <IMG src="MicrosoftTeams-image.png" width="750" height="180">

# %% [markdown]
# ### 1. Gerekli kütüphaneleri import ediyoruz.

# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn as sk

# %% [markdown]
# ### 2. Datasetimizi (cifar10 verisetini) yüklüyoruz: (Yükleme işlemi için Internet bağlantınızın olması gerekiyor). Eğer bağlantınız yoksa  veri setini Internetten indirip de yükleyebilirsiniz..

# %%
(x_train, y_train), (x_test,y_test) = datasets.cifar10.load_data()

# %%
# Verilerin class'ını kontrol ediyoruz.
print(type(x_train))
print(type(y_train))
print(type(x_test))
print(type(y_test))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %%
# Veri şeklini kontrol edelim.
x_train.shape , y_train.shape , x_test.shape, y_test.shape
# Out:
# ((50000, 32, 32, 3), (50000, 1), (10000, 32, 32, 3), (10000, 1))

# %% [markdown]
# ###  3. Train verisinden ilk 36 resmi görüntüleyelim.

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(24):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %% [markdown]
# ### 4. Verilere bir göz atalım. Bu amaçla kendimiz bir array oluşturuyoruz:

# %%
resim_siniflari = ["airplane","automobile","bird","cat","deer","dog","frog","horse","ship","truck"]

# %%
def plot_sample(x, y, index):
    plt.figure(figsize = (15,2))
    plt.imshow(x[index])        
    plt.show()

# %%
plot_sample(x_test, y_test, 1)

# %%
plot_sample(x_test, y_test, 5)

# %% [markdown]
# ###  5. Normalizasyon
# ###  Her Görüntüdeki Her Piksel'i 255'e Bölerek Görüntüleri Yeniden Ölçeklendiriyoruz.
#
# Verilerimizi normalize etmemiz gerekiyor. Aksi takdirde CNN algoritmaları yanlış sonuç verebiliyor. Fotoğraflar RGB olarak 3 kanal ve her bir pixel 0-255 arasında değer aldığı için normalization için basitçe her bir pixel değerini 255'e bölmemiz yeterli..

# %%
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %% [markdown]
# ### 6.  Veri Kümesini Eğitim, Test ve Doğrulama Kümelerine Bölüyoruz.

# %%
from keras.utils import np_utils
import tensorflow
from tensorflow.keras.utils import to_categorical

# One Hot Encoding, kategorik verilerin temsilinin daha etkileyici ve kolay olmasını sağlar.
num_classes = len(np.unique(y_train))
y_train = tensorflow.keras.utils.to_categorical(y_train, num_classes)
y_test = tensorflow.keras.utils.to_categorical(y_test, num_classes)

# Eğitim setini, eğitim ve doğrulama setlerine ayırıyoruz.
(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# Eğitim setinin şeklini yazdır.
print('x_train shape:', x_train.shape)

# Eğitim, doğrulama ve test görüntülerinin sayısını yazdırıyoruz.
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_valid.shape[0], 'validation samples')
# Out:
# x_train shape: (45000, 32, 32, 3)
# 45000 train samples
# 10000 test samples
# 5000 validation samples

# %% [markdown]
# ###  7. Modelimizi tanımlıyoruz.
# #### Bu kısım Convolution layer.. Bu kısımda fotoğraflardan tanımlama yapabilmek için özellikleri çıkarıyoruz...

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
# relu en iyi sonucu verdiği için kullanıldı.
model = Sequential()

model.add(Conv2D(16, (3,3), padding='same', activation='relu', 
                        input_shape=(32, 32, 3))) # Her bir image (32x32x3) olacak.
model.add(Conv2D(16,(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.25))

model.add(Conv2D(32, (3,3), padding='same', activation='relu'))
model.add(Conv2D(32,(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.35))

model.add(Conv2D(64, (3,3), padding='same', activation='relu'))
model.add(Conv2D(64,(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.45))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.55))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 32, 32, 16)        448
#
#  conv2d_7 (Conv2D)           (None, 30, 30, 16)        2320
#
#  max_pooling2d_3 (MaxPooling  (None, 15, 15, 16)       0
#  2D)
#
#  dropout_4 (Dropout)         (None, 15, 15, 16)        0
#
#  conv2d_8 (Conv2D)           (None, 15, 15, 32)        4640
#
#  conv2d_9 (Conv2D)           (None, 13, 13, 32)        9248
#
#  max_pooling2d_4 (MaxPooling  (None, 6, 6, 32)         0
#  2D)
#
#  dropout_5 (Dropout)         (None, 6, 6, 32)          0
#
#  conv2d_10 (Conv2D)          (None, 6, 6, 64)          18496
#
#  conv2d_11 (Conv2D)          (None, 4, 4, 64)          36928
#
#  max_pooling2d_5 (MaxPooling  (None, 2, 2, 64)         0
#  2D)
#
#  dropout_6 (Dropout)         (None, 2, 2, 64)          0
#
#  flatten_1 (Flatten)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 512)               131584
#
#  dropout_7 (Dropout)         (None, 512)               0
#
#  dense_3 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 208,794
# Trainable params: 208,794
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 8. Modeli Derliyoruz.

# %%
from keras import optimizers
# optimizer öğrenme oranını kontrol eder.
# RMSprop öğrenme oranını bir hiperparametre olarak değerlendirmek yerine uyarlanabilir bir öğrenme oranı kullanır.
RMSprop = tensorflow.keras.optimizers.RMSprop(learning_rate=0.0001, decay=1e-6)
model.compile(loss='categorical_crossentropy', optimizer=RMSprop, 
                  metrics=['accuracy'])

# %% [markdown]
# ### 9. Modeli Eğitiyoruz.

# %%
# batch_size bir seferde eğitilecek örnek sayısı
# epoch Bütün veri kümesinin yapay sinir ağından bir kere geçmesine denir.
# Verbose = 2 -> Her bir epoch sonunda tek bir satır olarak bize çıktı verir.
# Shuffle her bir epochs'tan önce verilerin yerlerinin değiştirilmesi için kullanılır.
hist = model.fit(x_train, y_train, batch_size=32, epochs=80,
        validation_data=(x_valid, y_valid), 
          verbose=2, shuffle=True)
# Out:
# Epoch 1/80
# 1407/1407 - 40s - loss: 2.1067 - accuracy: 0.1942 - val_loss: 1.9098 - val_accuracy: 0.3014 - 40s/epoch - 28ms/step
# Epoch 2/80
# 1407/1407 - 41s - loss: 1.8332 - accuracy: 0.2983 - val_loss: 1.7266 - val_accuracy: 0.3520 - 41s/epoch - 29ms/step
# Epoch 3/80
# 1407/1407 - 42s - loss: 1.7066 - accuracy: 0.3613 - val_loss: 1.5637 - val_accuracy: 0.4194 - 42s/epoch - 30ms/step
# Epoch 4/80
# 1407/1407 - 41s - loss: 1.6058 - accuracy: 0.4033 - val_loss: 1.5981 - val_accuracy: 0.4118 - 41s/epoch - 29ms/step
# Epoch 5/80
# 1407/1407 - 41s - loss: 1.5402 - accuracy: 0.4301 - val_loss: 1.4177 - val_accuracy: 0.4762 - 41s/epoch - 29ms/step
# Epoch 6/80
# 1407/1407 - 41s - loss: 1.4847 - accuracy: 0.4526 - val_loss: 1.3457 - val_accuracy: 0.5088 - 41s/epoch - 29ms/step
# Epoch 7/80
# 1407/1407 - 41s - loss: 1.4421 - accuracy: 0.4739 - val_loss: 1.3554 - val_accuracy: 0.5034 - 41s/epoch - 29ms/step
# Epoch 8/80
# 1407/1407 - 41s - loss: 1.3996 - accuracy: 0.4922 - val_loss: 1.3528 - val_accuracy: 0.5152 - 41s/epoch - 29ms/step
# Epoch 9/80
# 1407/1407 - 42s - loss: 1.3679 - accuracy: 0.5031 - val_loss: 1.2618 - val_accuracy: 0.5382 - 42s/epoch - 30ms/step
# Epoch 10/80
# 1407/1407 - 41s - loss: 1.3389 - accuracy: 0.5145 - val_loss: 1.2648 - val_accuracy: 0.5426 - 41s/epoch - 29ms/step
# Epoch 11/80
# 1407/1407 - 41s - loss: 1.3090 - accuracy: 0.5282 - val_loss: 1.1938 - val_accuracy: 0.5668 - 41s/epoch - 29ms/step
# Epoch 12/80
# 1407/1407 - 41s - loss: 1.2903 - accuracy: 0.5350 - val_loss: 1.1987 - val_accuracy: 0.5718 - 41s/epoch - 29ms/step
# Epoch 13/80
# 1407/1407 - 41s - loss: 1.2607 - accuracy: 0.5436 - val_loss: 1.2444 - val_accuracy: 0.5360 - 41s/epoch - 29ms/step
# Epoch 14/80
# 1407/1407 - 41s - loss: 1.2368 - accuracy: 0.5550 - val_loss: 1.1041 - val_accuracy: 0.6076 - 41s/epoch - 29ms/step
# Epoch 15/80
# 1407/1407 - 41s - loss: 1.2196 - accuracy: 0.5616 - val_loss: 1.1041 - val_accuracy: 0.5962 - 41s/epoch - 29ms/step
# Epoch 16/80
# 1407/1407 - 42s - loss: 1.2016 - accuracy: 0.5690 - val_loss: 1.1639 - val_accuracy: 0.5848 - 42s/epoch - 30ms/step
# Epoch 17/80
# 1407/1407 - 41s - loss: 1.1841 - accuracy: 0.5751 - val_loss: 1.0408 - val_accuracy: 0.6282 - 41s/epoch - 29ms/step
# Epoch 18/80
# 1407/1407 - 41s - loss: 1.1635 - accuracy: 0.5848 - val_loss: 1.1096 - val_accuracy: 0.6092 - 41s/epoch - 29ms/step
# Epoch 19/80
# 1407/1407 - 41s - loss: 1.1500 - accuracy: 0.5878 - val_loss: 1.0536 - val_accuracy: 0.6252 - 41s/epoch - 29ms/step
# Epoch 20/80
# 1407/1407 - 41s - loss: 1.1428 - accuracy: 0.5941 - val_loss: 0.9985 - val_accuracy: 0.6412 - 41s/epoch - 29ms/step
# Epoch 21/80
# 1407/1407 - 42s - loss: 1.1238 - accuracy: 0.5980 - val_loss: 0.9748 - val_accuracy: 0.6548 - 42s/epoch - 30ms/step
# Epoch 22/80
# 1407/1407 - 41s - loss: 1.1114 - accuracy: 0.6042 - val_loss: 0.9560 - val_accuracy: 0.6660 - 41s/epoch - 29ms/step
# Epoch 23/80
# 1407/1407 - 41s - loss: 1.0963 - accuracy: 0.6077 - val_loss: 1.1216 - val_accuracy: 0.6084 - 41s/epoch - 29ms/step
# Epoch 24/80
# 1407/1407 - 41s - loss: 1.0831 - accuracy: 0.6113 - val_loss: 0.9956 - val_accuracy: 0.6506 - 41s/epoch - 29ms/step
# Epoch 25/80
# 1407/1407 - 41s - loss: 1.0739 - accuracy: 0.6186 - val_loss: 1.0403 - val_accuracy: 0.6356 - 41s/epoch - 29ms/step
# Epoch 26/80
# 1407/1407 - 41s - loss: 1.0674 - accuracy: 0.6202 - val_loss: 0.9610 - val_accuracy: 0.6584 - 41s/epoch - 29ms/step
# Epoch 27/80
# 1407/1407 - 41s - loss: 1.0572 - accuracy: 0.6270 - val_loss: 0.9386 - val_accuracy: 0.6658 - 41s/epoch - 29ms/step
# Epoch 28/80
# 1407/1407 - 41s - loss: 1.0442 - accuracy: 0.6276 - val_loss: 0.9678 - val_accuracy: 0.6552 - 41s/epoch - 29ms/step
# Epoch 29/80
# 1407/1407 - 41s - loss: 1.0370 - accuracy: 0.6325 - val_loss: 0.9174 - val_accuracy: 0.6774 - 41s/epoch - 29ms/step
# Epoch 30/80
# 1407/1407 - 41s - loss: 1.0296 - accuracy: 0.6350 - val_loss: 0.8794 - val_accuracy: 0.6860 - 41s/epoch - 29ms/step
# Epoch 31/80
# 1407/1407 - 41s - loss: 1.0198 - accuracy: 0.6428 - val_loss: 0.9125 - val_accuracy: 0.6816 - 41s/epoch - 29ms/step
# Epoch 32/80
# 1407/1407 - 43s - loss: 1.0106 - accuracy: 0.6442 - val_loss: 0.8971 - val_accuracy: 0.6858 - 43s/epoch - 31ms/step
# Epoch 33/80
# 1407/1407 - 42s - loss: 0.9978 - accuracy: 0.6486 - val_loss: 0.8694 - val_accuracy: 0.7032 - 42s/epoch - 30ms/step
# Epoch 34/80
# 1407/1407 - 41s - loss: 0.9990 - accuracy: 0.6479 - val_loss: 0.9122 - val_accuracy: 0.6838 - 41s/epoch - 29ms/step
# Epoch 35/80
# 1407/1407 - 41s - loss: 0.9855 - accuracy: 0.6540 - val_loss: 0.8616 - val_accuracy: 0.7004 - 41s/epoch - 29ms/step
# Epoch 36/80
# 1407/1407 - 41s - loss: 0.9813 - accuracy: 0.6544 - val_loss: 0.8420 - val_accuracy: 0.7058 - 41s/epoch - 29ms/step
# Epoch 37/80
# 1407/1407 - 41s - loss: 0.9739 - accuracy: 0.6602 - val_loss: 0.8506 - val_accuracy: 0.7058 - 41s/epoch - 29ms/step
# Epoch 38/80
# 1407/1407 - 41s - loss: 0.9727 - accuracy: 0.6599 - val_loss: 0.8768 - val_accuracy: 0.6890 - 41s/epoch - 29ms/step
# Epoch 39/80
# 1407/1407 - 41s - loss: 0.9613 - accuracy: 0.6629 - val_loss: 0.8293 - val_accuracy: 0.7158 - 41s/epoch - 29ms/step
# Epoch 40/80
# 1407/1407 - 41s - loss: 0.9548 - accuracy: 0.6655 - val_loss: 0.8529 - val_accuracy: 0.7034 - 41s/epoch - 29ms/step
# Epoch 41/80
# 1407/1407 - 41s - loss: 0.9550 - accuracy: 0.6691 - val_loss: 0.8586 - val_accuracy: 0.7040 - 41s/epoch - 29ms/step
# Epoch 42/80
# 1407/1407 - 41s - loss: 0.9483 - accuracy: 0.6685 - val_loss: 0.8490 - val_accuracy: 0.7132 - 41s/epoch - 29ms/step
# Epoch 43/80
# 1407/1407 - 42s - loss: 0.9412 - accuracy: 0.6715 - val_loss: 0.8817 - val_accuracy: 0.6932 - 42s/epoch - 30ms/step
# Epoch 44/80
# 1407/1407 - 42s - loss: 0.9417 - accuracy: 0.6701 - val_loss: 0.8332 - val_accuracy: 0.7140 - 42s/epoch - 30ms/step
# Epoch 45/80
# 1407/1407 - 41s - loss: 0.9348 - accuracy: 0.6754 - val_loss: 0.8184 - val_accuracy: 0.7226 - 41s/epoch - 29ms/step
# Epoch 46/80
# 1407/1407 - 41s - loss: 0.9333 - accuracy: 0.6771 - val_loss: 0.9138 - val_accuracy: 0.6868 - 41s/epoch - 29ms/step
# Epoch 47/80
# 1407/1407 - 41s - loss: 0.9268 - accuracy: 0.6771 - val_loss: 0.7977 - val_accuracy: 0.7296 - 41s/epoch - 29ms/step
# Epoch 48/80
# 1407/1407 - 41s - loss: 0.9230 - accuracy: 0.6798 - val_loss: 0.8179 - val_accuracy: 0.7164 - 41s/epoch - 29ms/step
# Epoch 49/80
# 1407/1407 - 41s - loss: 0.9190 - accuracy: 0.6818 - val_loss: 0.8314 - val_accuracy: 0.7262 - 41s/epoch - 29ms/step
# Epoch 50/80
# 1407/1407 - 41s - loss: 0.9127 - accuracy: 0.6835 - val_loss: 0.8778 - val_accuracy: 0.7020 - 41s/epoch - 29ms/step
# Epoch 51/80
# 1407/1407 - 41s - loss: 0.9094 - accuracy: 0.6855 - val_loss: 0.7738 - val_accuracy: 0.7350 - 41s/epoch - 29ms/step
# Epoch 52/80
# 1407/1407 - 41s - loss: 0.9096 - accuracy: 0.6860 - val_loss: 0.7950 - val_accuracy: 0.7254 - 41s/epoch - 29ms/step
# Epoch 53/80
# 1407/1407 - 41s - loss: 0.9099 - accuracy: 0.6846 - val_loss: 0.7814 - val_accuracy: 0.7312 - 41s/epoch - 29ms/step
# Epoch 54/80
# 1407/1407 - 41s - loss: 0.9011 - accuracy: 0.6892 - val_loss: 0.8545 - val_accuracy: 0.7148 - 41s/epoch - 29ms/step
# Epoch 55/80
# 1407/1407 - 41s - loss: 0.8947 - accuracy: 0.6914 - val_loss: 0.8260 - val_accuracy: 0.7248 - 41s/epoch - 29ms/step
# Epoch 56/80
# 1407/1407 - 41s - loss: 0.8961 - accuracy: 0.6905 - val_loss: 0.7990 - val_accuracy: 0.7334 - 41s/epoch - 29ms/step
# Epoch 57/80
# 1407/1407 - 41s - loss: 0.8914 - accuracy: 0.6923 - val_loss: 0.7888 - val_accuracy: 0.7360 - 41s/epoch - 29ms/step
# Epoch 58/80
# 1407/1407 - 41s - loss: 0.8898 - accuracy: 0.6917 - val_loss: 0.7933 - val_accuracy: 0.7348 - 41s/epoch - 29ms/step
# Epoch 59/80
# 1407/1407 - 55s - loss: 0.8926 - accuracy: 0.6929 - val_loss: 0.7809 - val_accuracy: 0.7396 - 55s/epoch - 39ms/step
# Epoch 60/80
# 1407/1407 - 56s - loss: 0.8823 - accuracy: 0.6925 - val_loss: 0.7991 - val_accuracy: 0.7296 - 56s/epoch - 40ms/step
# Epoch 61/80
# 1407/1407 - 42s - loss: 0.8901 - accuracy: 0.6936 - val_loss: 0.8295 - val_accuracy: 0.7156 - 42s/epoch - 30ms/step
# Epoch 62/80
# 1407/1407 - 42s - loss: 0.8858 - accuracy: 0.6940 - val_loss: 0.7978 - val_accuracy: 0.7332 - 42s/epoch - 30ms/step
# Epoch 63/80
# 1407/1407 - 41s - loss: 0.8814 - accuracy: 0.6978 - val_loss: 0.7806 - val_accuracy: 0.7368 - 41s/epoch - 29ms/step
# Epoch 64/80
# 1407/1407 - 41s - loss: 0.8725 - accuracy: 0.7006 - val_loss: 0.7860 - val_accuracy: 0.7398 - 41s/epoch - 29ms/step
# Epoch 65/80
# 1407/1407 - 42s - loss: 0.8786 - accuracy: 0.6974 - val_loss: 0.7862 - val_accuracy: 0.7396 - 42s/epoch - 30ms/step
# Epoch 66/80
# 1407/1407 - 46s - loss: 0.8765 - accuracy: 0.7001 - val_loss: 0.8334 - val_accuracy: 0.7194 - 46s/epoch - 32ms/step
# Epoch 67/80
# 1407/1407 - 42s - loss: 0.8726 - accuracy: 0.7011 - val_loss: 0.7575 - val_accuracy: 0.7486 - 42s/epoch - 30ms/step
# Epoch 68/80
# 1407/1407 - 43s - loss: 0.8725 - accuracy: 0.7020 - val_loss: 0.7692 - val_accuracy: 0.7478 - 43s/epoch - 30ms/step
# Epoch 69/80
# 1407/1407 - 42s - loss: 0.8655 - accuracy: 0.7037 - val_loss: 0.7739 - val_accuracy: 0.7518 - 42s/epoch - 30ms/step
# Epoch 70/80
# 1407/1407 - 42s - loss: 0.8616 - accuracy: 0.7037 - val_loss: 0.9838 - val_accuracy: 0.6828 - 42s/epoch - 30ms/step
# Epoch 71/80
# 1407/1407 - 42s - loss: 0.8734 - accuracy: 0.7012 - val_loss: 0.7673 - val_accuracy: 0.7490 - 42s/epoch - 30ms/step
# Epoch 72/80
# 1407/1407 - 42s - loss: 0.8622 - accuracy: 0.7047 - val_loss: 0.7713 - val_accuracy: 0.7492 - 42s/epoch - 30ms/step
# Epoch 73/80
# 1407/1407 - 42s - loss: 0.8613 - accuracy: 0.7078 - val_loss: 0.7542 - val_accuracy: 0.7502 - 42s/epoch - 30ms/step
# Epoch 74/80
# 1407/1407 - 42s - loss: 0.8565 - accuracy: 0.7081 - val_loss: 0.8126 - val_accuracy: 0.7458 - 42s/epoch - 30ms/step
# Epoch 75/80
# 1407/1407 - 42s - loss: 0.8601 - accuracy: 0.7077 - val_loss: 0.7989 - val_accuracy: 0.7490 - 42s/epoch - 30ms/step
# Epoch 76/80
# 1407/1407 - 43s - loss: 0.8591 - accuracy: 0.7059 - val_loss: 0.7637 - val_accuracy: 0.7478 - 43s/epoch - 31ms/step
# Epoch 77/80
# 1407/1407 - 42s - loss: 0.8591 - accuracy: 0.7067 - val_loss: 0.8530 - val_accuracy: 0.7208 - 42s/epoch - 30ms/step
# Epoch 78/80
# 1407/1407 - 42s - loss: 0.8579 - accuracy: 0.7080 - val_loss: 0.8021 - val_accuracy: 0.7432 - 42s/epoch - 30ms/step
# Epoch 79/80
# 1407/1407 - 42s - loss: 0.8569 - accuracy: 0.7084 - val_loss: 0.7811 - val_accuracy: 0.7438 - 42s/epoch - 30ms/step
# Epoch 80/80
# 1407/1407 - 42s - loss: 0.8542 - accuracy: 0.7092 - val_loss: 0.7817 - val_accuracy: 0.7370 - 42s/epoch - 30ms/step

# %% [markdown]
# ### 10. Test setindeki doğruluğu hesaplıyoruz.

# %%
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.734000027179718

# %% [markdown]
# ### 11. Accuracy değelerini grafikler üzerinde gösteriyoruz.

# %%
# Accuracy grafiği oluşturmak için değer atıyoruz.
acc = hist.history['accuracy'] 
val_acc =  hist.history['val_accuracy'] 
loss = hist.history['loss'] 
val_loss = hist.history['val_loss'] 

len_acc = len(acc) 
len_val_acc = len(val_acc)
len_loss = len(loss)
len_val_loss = len(val_loss)

# Sonuçları görüntülüyoruz.
fig, axs = plt.subplots(1, 2, figsize=(15, 5))

# Accuracy değeri
axs[0].plot(range(1, len_acc + 1), acc)
axs[0].plot(range(1, len_val_acc + 1), val_acc)
axs[0].set_title('Model Accuracy')
axs[0].set_ylabel('Accuracy')
axs[0].set_xlabel('Epoch')
axs[0].set_xticks(np.arange(1, len_acc + 1), len_acc / 10)
axs[0].legend(['train', 'val'], loc='best')

# Loss değeri
axs[1].plot(range(1, len_loss +1), loss)
axs[1].plot(range(1, len_val_loss +1), val_loss)
axs[1].set_title('Model Loss')
axs[1].set_ylabel('Loss')
axs[1].set_xlabel('Epoch')
axs[1].set_xticks(np.arange(1, len_loss + 1), len_loss / 10)
axs[1].legend(['train', 'val'], loc='best')
plt.show()

# %% [markdown]
# ### 12. Bazı tahminleri görselleştiriyoruz.

# %%
# Test setinden tahminleri alıyoruz.
y_hat = model.predict(x_test)

# Metin etikelerini tanımlıyoruz. 
cifar10_labels = ['Uçak', 'Otomobil', 'Kuş', 'Kedi', 'Geyik', 'Köpek', 'Kurbağa', 'At', 'Gemi', 'Kamyonet']

# %%
# Bu kısımda rastgele bir test görüntüsü örneği, tahmin edilen etiketler ve temel gerçeği çizin
fig = plt.figure(figsize=(20, 8))
for i, idx in enumerate(np.random.choice(x_test.shape[0], size=32, replace=False)):
    ax = fig.add_subplot(4, 8, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_test[idx]))
    pred_idx = np.argmax(y_hat[idx])
    true_idx = np.argmax(y_test[idx])
    ax.set_title("{} ({})".format(cifar10_labels[pred_idx], cifar10_labels[true_idx]),
                 color=("green" if pred_idx == true_idx else "red"))
